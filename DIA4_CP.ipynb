# %% [markdown]
# DIA 4

# %% [markdown]
# Temario
# - Funciones
# - Funciones Lambda
# - Errores (excepcionales)

# %% [markdown]
# FUNCIONES

# %% [markdown]
# En este curso hemos usado algunas funciones integradas en python, pero tambien nosotros podemos definir funciones, siendo estas un bloque de codigo reutilizable que podemos mandar a llamar varias veces en el codigo

# %%
def mensaje():
  print("Hola!!!")

mensaje()
# Out:
# Hola!!!

# %%
# Funcion con retorno
def mensaje():
  return "Hola!!!"
print(mensaje())
va = mensaje()
print(va)
# Out:
# Hola!!!
# Hola!!!

# %%
def saludo(nombre):
  print(f"Hola", nombre, "!!!")

tuNombre = input("Ingresa tu nombre: ")
saludo(tuNombre)
# Nota: El nombre de la variable del parametro puede o no ser el mismo fuera de la funcion
# Out:
# Ingresa tu nombre: Natalia
# Hola Natalia !!!

# %%
# Puedes mandarle el parametro de esta manera
saludo("Grupo")
# Out:
# Hola Grupo !!!

# %%
def suma(numero_1, numero_2):
  return numero_1 + numero_2

suma = suma(1, 5)
print(suma)
# Out:
# 6

# %%
def bienvenida(nombre = "invitado"):
  print("Hola", nombre)

bienvenida()
bienvenida("Victor")
# Out:
# Hola invitado
# Hola Victor

# %%
def suma(numero_1 = 2, numero_2 = 10):
  return numero_1 + numero_2
suma = suma(100000, 15324342)
print(suma)
# Out:
# 15424342

# %%
# Descuento
def descuento(precio, desc = 0.15):
  precio = precio * (1 - desc)
  print("El nuevo precio es: ",precio)
descuento(750)
descuento(800,0.25)
# Out:
# El nuevo precio es:  637.5
# El nuevo precio es:  600.0

# %%
def usuario(nombre,edad):
  return (nombre,edad)
persona = usuario("Victor",21)
print(type(persona))
print(persona)
# Out:
# <class 'tuple'>
# ('Victor', 21)

# %%
def operaciones(numero):
  doble = numero * 2
  triple = numero * 3
  cuadruple = numero * 4
  quintuple = numero * 5
  return doble, triple, cuadruple, quintuple
resultado = operaciones(2)
print(resultado)
# Out:
# (4, 6, 8, 10)

# %% [markdown]
# FUNCIONES QUE LLAMAN A OTRAS FUNCIONES

# %%
def saludar(nombre):
  return f"Hola, {nombre}!"

def despedirse(nombre):
  return f"Adiós, {nombre}!"

def mensaje_completo(nombre):
  saludo = saludar(nombre)
  despedida = despedirse(nombre)
  return saludo + " " + despedida

print(mensaje_completo("Ana"))
# Out:
# Hola, Ana! Adiós, Ana!

# %%
# Ahora supongamos que tenemos una heladeria
def pedir_sabor():
  sabores = ["vainilla", "chocolate","fresa"]
  print("Sabor disponible", ",", sabores)
  # lower() hace minusculas las palabras
  # strip() elimina los espacios tanto antes como despues
  sabor = input("Elige un sabor: ").strip().lower()
  # si sabor NO esta en sabores
  while sabor not in sabores:
    sabor = input("Elige un sabor (nuevamente): ").strip().lower()
  return sabor

def pedir_cantidad():
  cantidad = int(input("Cuantas bolas de nieve ?: ") )
  while cantidad <= 0:
    cantidad = int(input("Cuantas bolas de nieve? (ingresa un valor valido) : "))
  return cantidad
# Funcion Madre (llama a otras funciones)
def pedir_helado():
  sabor = pedir_sabor()
  cant = pedir_cantidad()
  print(f"Pedido: {cant} bola(s) de {sabor}")
  return cant, sabor

total_pedidos = int(input("Cuantos clientes atenderas?: "))
for i in range(total_pedidos):
  pedir_helado()
# Out:
# Cuantos clientes atenderas?: 2
# Sabor disponible , ['vainilla', 'chocolate', 'fresa']
# Elige un sabor: chocolate
# Cuantas bolas de nieve ?: 2
# Pedido: 2 bola(s) de chocolate
# Sabor disponible , ['vainilla', 'chocolate', 'fresa']
# Elige un sabor: fresa
# Cuantas bolas de nieve ?: 3
# Pedido: 3 bola(s) de fresa

# %% [markdown]
# FUNCIONES LAMBDA

# %% [markdown]
# Una funcion lambda es una funcion acortada para escribir una funcion de esta forma:
#
# nombreFuncion = lambda parametros: accion
#
# La diferecncia entre las funciones lambda y las funciones normales es que suelen ser un poco mas limitadas

# %%
sumar = lambda x,y : x+y
print(sumar(3,10))
# Out:
# 13

# %%
descuentoLambda = lambda desc, precio: ((precio * (1 - desc)),(precio * desc))
nuevoPrecio = descuentoLambda(0.4,500)
print("El nuevo a pagar es", nuevoPrecio[0], ", el descuento que se hizo fue de: ", nuevoPrecio[1])
print(type(nuevoPrecio))
# Out:
# El nuevo a pagar es 300.0 , el descuento que se hizo fue de:  200.0
# <class 'tuple'>

# %% [markdown]
# ERRORES (EXCEPCIONES)

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-179726827.py in <cell line: 0>()
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
try:
  dividiendo = float(input("Ingresa el dividendo: "))
  divisor = float(input("Ingresa el divisor: "))
  division = dividiendo / divisor
  print(division)
except ZeroDivisionError:
  print("Error: el divisor no debe de ser cero")
# Out:
# Ingresa el dividendo: 10
# Ingresa el divisor: 0
# Error: el divisor no debe de ser cero

# %%
# Tambien podemos manejar mas de una excepcion, por ejemplo, con la dicision
# podemos tener el tipo de valor como el de la division entre 0

try:
  numero = int(input("escriba un numero: "))
  print(numero)
except ValueError:
  print("Ingresa un valor numerico")
# Out:
# escriba un numero: hola
# Ingresa un valor numerico

# %%
# Tambien podemos manejar mas de una excepcion, por ejemplo, con la dicision
# podemos tener el tipo de valor como el de la division entre 0
try:
  dividiendo = float(input("Ingresa el dividendo: "))
  divisor = float(input("Ingresa el divisor: "))
  division = dividiendo / divisor
  print(division)
except ZeroDivisionError:
  print("Error: el divisor no debe de ser cero")
except ValueError:
  print("Error: Ingresa un valor numerico")
# Out:
# Ingresa el dividendo: 9
# Ingresa el divisor: hola
# Error: Ingresa un valor numerico

# %%
# Calculadora -> suma, resta, producto, division y potencia
def suma(a,b):
  return a + b
def resta(a,b):
  return a - b
def producto(a,b):
  return a * b
def division(a,b):
  if b == 0:
    return "Error: no se puede dividir entre 0"
  return a / b
def potencia(a,b):
  return a ** b

def menu():
  print("--------MI CALCULADORA--------")
  print("1. Suma")
  print("2. Resta")
  print("3. Producto")
  print("4. División")
  print("5. Potencia")
  print("6. Salir")

while True:
  menu()
  try:
    op = int(input("seleccione una opcion: "))
    if op < 1 or op > 6:
       print("Opcion invalida")

  except ValueError:
    print("Ingrese un numero valido")
  if op == 6:
    print("SALIENDO...")
    break

  try:
    a = float(input("Ingrese el primer numero: "))
    b = float(input("Ingrese el segundo numero: "))
  except ValueError:
    print("Ingrese un numero valido")
  if op == 1:
    print("Resultado:", suma(a,b))
  elif op == 2:
    print("Resultado:", resta(a,b))
  elif op == 3:
    print("Resultado:", producto(a,b))
  elif op == 4:
    print("Resultado:", division(a,b))
  elif op == 5:
    print("Resultado:", potencia(a,b))
  else:
    print("Opcion invalida")
# Out:
# --------MI CALCULADORA--------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# seleccione una opcion: 2
# Ingrese el primer numero: 3
# Ingrese el segundo numero: 3
# Resultado: 0.0
# --------MI CALCULADORA--------
# 1. Suma
# 2. Resta
# 3. Producto
# 4. División
# 5. Potencia
# 6. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3150391258.py in <cell line: 0>()
#      25   menu()
#      26   try:
# ---> 27     op = int(input("seleccione una opcion: "))
#      28     if op < 1 or op > 6:
#      29        print("Opcion invalida")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
