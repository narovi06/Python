# %% [markdown]
# DIA 6

# %% [markdown]
# Programacion orientada a objetos
#
# Temario
# - ¿Que es POO?
# - Entidades: Clases y Objetos
# - self, __init__ y el ciclo de vida de un objeto
# - Atributos: de instancia vs de clase
# - Metodo: instancia, clase
# - Encapsulamiento y propiedades
# - Herecia y Abstraccion
# - Polimorfismo
# - Composicion vs Herencia

# %% [markdown]
# QUE ES POO Y PORQUE USARLA

# %%
1. Clases (los molde): Una clase es como el molde o plano para crear algo
2. Objetos (Las creaciones): Un objeto es una instancia real tangible creada a partir de una clase

# %% [markdown]
# ENTIDADES: CLASES Y OBJETOS

# %%
class Perro: # creaste tu clase
    def ladrar(self): # metodo
        print("Guau!")

mi_perro = Perro() # creación de tu objeto
mi_perro.ladrar()
# Out:
# Guau!

# %% [markdown]
# SELF, __INIT__ Y EL CICLO DE VIDA DE UN OBJETO

# %%
class Perro:
# self es la referencia a la instancia actual, __init__
    def __init__(self, nombre, edad): # metodo constructor
        self.nombre = nombre
        self.edad = edad
    def presentarse(self):
        print(f"Soy {self.nombre} y tengo {self.edad} años")
naylah = Perro("Naylah", 5)
naylah.presentarse()

# __init__  no retorna la instancia; Python lo llama al crear el objeto
# Evita usar valores mutables como parametros por defectos
# Out:
# Soy Naylah y tengo 5 años

# %% [markdown]
# ATRIBUTOS: DE INSTANCIA VS DE CLASE

# %%
class Perro:
  patas = 4
  especie = "Caninis Familiaris" # atributos de clase
  def __init__(self,nombre):
     self.nombre = nombre # atributos de instancia
p1 = Perro("firulais")
p2 = Perro("bobby")
print(p1.especie)
print(p2.especie)
print("------------------")
p2.especie = "Gato"
print(p1.especie)
print(p2.especie) # cambio el atributo de la clase especialmente para p2
# Out:
# Caninis Familiaris
# Caninis Familiaris
# ------------------
# Caninis Familiaris
# Gato

# %%
print(p1.__dict__)
print(p2.__dict__)
# Out:
# {'nombre': 'firulais'}
# {'nombre': 'bobby', 'especie': 'Gato'}

# %% [markdown]
# METODOS DE INSTANCIA, CLASE

# %% [markdown]
# Un metodo de instancia es una funcion definida dentro de una clase que:
# - Opera sobre un objeto concreto (una instancia)
# - Puede acceder y modificar los atributos de ese objeto
# - Recibe como primer parametro a self

# %%
# (ya lo hemos usado)
class tuClase:
    def metodo(self):
        pass

# metodo -> metodo de instancia
# self -> referencia al objeto que llama al metodo

# %%
# Calculadora
class Calculadora:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2
    def sumar(self):
        print(self.num1 + self.num2)
    def restar(self):
        print(self.num1 - self.num2)
    def multiplicar(self):
        print(self.num1 * self.num2)
    def dividir(self):
        if self.num2 == 0:
            print("No se puede dividir por cero")
        else:
            print(self.num1 / self.num2)
Calculadora = Calculadora(7,0)
Calculadora.dividir()
Calculadora.multiplicar()
Calculadora.restar()
Calculadora.sumar()
# Out:
# No se puede dividir por cero
# 0
# 7
# 7

# %%
# EJERCICIO, crear una clase animal, donde tenga una instancia de por lo menos 3 variables con 1 Metodo y crea 4 objetos
class Animal: #1 clase
    def __init__(self,nombre,especie,patas,comida_favorita,sonido): #2 instancia
        self.nombre = nombre #3 variables
        self.especie = especie
        self.patas = patas
        self.comida_favorita = comida_favorita
        self.sonido = sonido

    def hacer_sonido(self): #4 metodo
        print(self.sonido)

gato = Animal("Rayitas", "Gato", 4, "Carne de Res", "miau") #5 Objetos
perro = Animal("Mechas", "Perro", 4, "Pollito Asado", "woof")
pajaro = Animal("Paco", "Perico", 2, "Semillas", "pipipi")
vaca = Animal("Manchas", "Vaca", 4, "Pasto", "muuu")

vaca.hacer_sonido()
gato.nombre = "Juan"
gato.nombre
# Out:
# muuu
# 'Juan'

# %% [markdown]
# ENCAPSULAMIENTO Y PROPIEDADES

# %%
class Cuenta:
    def __init__(self,saldo):
        self.__sal = saldo # privada
# sieve para proteger los datos internos de un objeto y controlar como se leen o modifican
cuenta = Cuenta(1000)
cuenta.Cuenta = 2000 # si puedes editarlo
#print(cuenta.__saldo) # Error: no se puede acceder directamente

# %%
# Getters y Setters
class Cuenta:
    def __init__(self,saldo):
        self.__saldo = saldo
    @property
    def saldo(self): # getter
        # permite leer el valor de __saldo usando c.saldo
        return self.__saldo
    @saldo.setter # setter
    def saldo(self, valor):
        # se ejecuta cuando hacemos c.saldo = valor
        self.__saldo = valor

c = Cuenta(300)
print(c.saldo)
c.saldo = 4000
# Out:
# 300

# %% [markdown]
# HERENCIA Y ABSTRACCION

# %%
# Herencia
class Vehiculo:
    def __init__(self,marca,modelo):
        self.marca = marca
        self.modelo = modelo
    def descripcion(self):
        return f"{self.marca}:{self.modelo}"
    def mover(self):
        return "El vehiculo se esta moviendo..."
#---------------------------------------------------------------------

class Coche(Vehiculo): # subclase 1 (clase hija)
    def mover(self):
        return "El coche esta conduciendo"

#--------------------------------------------------------------------

class Moto(Vehiculo): # subclase 2 (clase hija)
    def mover(self):
        return "La moto avanza sobre dos ruedas"
coche2 = Vehiculo("BYD", "Dolphin")
coche = Coche("Toyota", "Corolla")
moto = Moto("Yamaha", "R6")
print(coche2.descripcion())
print(coche2.mover())
print(coche.descripcion())
# Out:
# BYD:Dolphin
# El vehiculo se esta moviendo...
# Toyota:Corolla

# %%
class Persona:
    def __init__ (self, nombre, edad):
        self.nombre = nombre
        self.edad = edad
    def presentarse(self):
        print(f"Hola, soy {self.nombre} y tengo {self.edad} años")
class Estudiante(Persona):
    def __init__(self, nombre, edad, carrera):
        super().__init__(nombre, edad)
        self.carrera = carrera
    def presentarse(self):
        super().presentarse()
        #print(f"Hola, soy {self.nombre} y tengo {self.edad} años")
        print(f"Estudio la carrera de {self.carrera}")
# reutiliza el constructor de la clase padre (lo cual evita duplicar el codigo)
# ejecuta el comportamiento base y luego lo extiende
est = Estudiante("Ana", 20, "Programacion")
est.presentarse()
# Out:
# Hola, soy Ana y tengo 20 años
# Estudio la carrera de Programacion

# %%
# Abstraccion
class Animal:
    def hablar(self):
        raise NotImplementedError
class Gato(Animal):
    def hablar(self):
        return "miau"

# %% [markdown]
# POLIMORFISMO

# %% [markdown]
# (justo ya lo implementamos), el polimorfismo significa que diferentes objetos pueden responder al ismo mensaje(metodo) de forma distinta, siempre y cuando compartan una interfaz comun

# %% [markdown]
# COMPOSICION HAS-A
# pq se le llama composición?
# pq estas componiendo (armado) un objeto grande usando otros objetos. Es un principio de POO donde:
# - Una clase No hereda de otra, si no que contiene un objeto de esa otra clase

# %%
class Banco:
    def __init__(self,dinero):
        self.dinero = dinero
    def ver_total(self):
        print(f"Total en la cuenta: ${self.dinero}")
class Persona:
    def __init__(self, cuenta: Banco): # indica que este parametro deberia ser una instancia de la clase Banco
        self.cuenta = cuenta # persona tiene un banco, no hereda de el

# %% [markdown]
# COMPOSICION VS HERENCIA

# %% [markdown]
# Esto se va a responder con pura:
# No significa que alguna sea mejor que otra simplemente que aveces una te puede convenir mas que otra:

# %% [markdown]
# - Herencia: un gato ES un animal (no "un gato tiene un animal")
# - Composicion: una persona tiene una cuenta (no "una persona es un banco")
